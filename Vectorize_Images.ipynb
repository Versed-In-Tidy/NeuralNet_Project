# %%
# Get libraries of interest 
import pandas as pd
import numpy as np 
import os

# %%
# The directory to our dataset(s)
BASE_DIR = "C:/Users/Zachery Key/Desktop/Forge/NeuralNet_Project"

PATH_INDEX = BASE_DIR + "/Images/index.csv"
PATH_TEST = BASE_DIR + "/Images/test.csv"
PATH_METADATA = BASE_DIR + "/Images/metadata.csv"

# %%
# Out:
#     class_id lego_ids                             lego_names  \
# 0          1  [76115]              ['Spider Mech vs. Venom']
# 1          2  [76115]              ['Spider Mech vs. Venom']
# 2          3  [76115]              ['Spider Mech vs. Venom']
# 3          4  [76115]              ['Spider Mech vs. Venom']
# 4          5  [75208]                         ["Yoda's Hut"]
# 5          6  [75208]                         ["Yoda's Hut"]
# 6          7  [75208]                         ["Yoda's Hut"]
# 7          8  [75199]   ["General Grievous' Combat Speeder"]
# 8          9  [75199]   ["General Grievous' Combat Speeder"]
# 9         10  [75264]    ["Kylo Ren's Shuttle Microfighter"]
# 10        11  [75254]  ["AT-ST Raider from The Mandalorian"]
# 11        12  [75254]  ["AT-ST Raider from The Mandalorian"]
# 12        13  [75254]  ["AT-ST Raider from The Mandalorian"]
# 13        14  [75254]  ["AT-ST Raider from The Mandalorian"]
# ...

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is DC54-CC99
#
#  Directory of C:\Users\Zachery Key\Desktop\Forge\NeuralNet_Project
#
# 06/07/2021  11:27 AM    <DIR>          .
# 06/07/2021  11:27 AM    <DIR>          ..
# 06/07/2021  11:22 AM    <DIR>          .ipynb_checkpoints
# 06/07/2021  10:48 AM    <DIR>          Images
# 06/07/2021  10:50 AM            26,230 Intro_Pytorch.ipynb
# 06/07/2021  10:50 AM                19 README.md
# 06/07/2021  11:27 AM             1,548 Vectorize_Images.ipynb
#                3 File(s)         27,797 bytes
#                4 Dir(s)  13,435,715,584 bytes free
